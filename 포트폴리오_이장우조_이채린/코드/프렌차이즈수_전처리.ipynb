# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
# 파일 불러오기
df= pd.read_csv("/Users/crlee/pandas/2022_점포수.csv",encoding = 'cp949')
df
# Out:
#         기준_년_코드  기준_분기_코드 상권_구분_코드 상권_구분_코드_명    상권_코드      상권_코드_명 서비스_업종_코드  \
# 0          2022         4        U       관광특구  1001496  강남 마이스 관광특구  CS300043
# 1          2022         4        U       관광특구  1001496  강남 마이스 관광특구  CS300042
# 2          2022         4        U       관광특구  1001496  강남 마이스 관광특구  CS300041
# 3          2022         4        U       관광특구  1001496  강남 마이스 관광특구  CS300038
# 4          2022         4        U       관광특구  1001496  강남 마이스 관광특구  CS300036
# ...         ...       ...      ...        ...      ...          ...       ...
# 898063     2020         1        A       골목상권  2110001       이북5도청사  CS200001
# 898064     2020         1        A       골목상권  2110001       이북5도청사  CS100010
# 898065     2020         1        A       골목상권  2110001       이북5도청사  CS100009
# 898066     2020         1        A       골목상권  2110001       이북5도청사  CS100008
# 898067     2020         1        A       골목상권  2110001       이북5도청사  CS100001
#
# ...

# %%
# 필요한 열만 추출
select_col = ['기준_년_코드','기준_분기_코드', '상권_구분_코드_명','상권_코드_명', '프랜차이즈_점포_수']
df2 = df[select_col]
df2
# Out:
#         기준_년_코드  기준_분기_코드 상권_구분_코드_명      상권_코드_명  프랜차이즈_점포_수
# 0          2022         4       관광특구  강남 마이스 관광특구           0
# 1          2022         4       관광특구  강남 마이스 관광특구           0
# 2          2022         4       관광특구  강남 마이스 관광특구           0
# 3          2022         4       관광특구  강남 마이스 관광특구           0
# 4          2022         4       관광특구  강남 마이스 관광특구           0
# ...         ...       ...        ...          ...         ...
# 898063     2020         1       골목상권       이북5도청사           0
# 898064     2020         1       골목상권       이북5도청사           0
# 898065     2020         1       골목상권       이북5도청사           1
# 898066     2020         1       골목상권       이북5도청사           0
# 898067     2020         1       골목상권       이북5도청사           1
#
# [898068 rows x 5 columns]

# %%
# 기준_년_코드 > 2022년만 추출
df3 = df2[df2['기준_년_코드'] == 2022]
df3
# Out:
#         기준_년_코드  기준_분기_코드 상권_구분_코드_명      상권_코드_명  프랜차이즈_점포_수
# 0          2022         4       관광특구  강남 마이스 관광특구           0
# 1          2022         4       관광특구  강남 마이스 관광특구           0
# 2          2022         4       관광특구  강남 마이스 관광특구           0
# 3          2022         4       관광특구  강남 마이스 관광특구           0
# 4          2022         4       관광특구  강남 마이스 관광특구           0
# ...         ...       ...        ...          ...         ...
# 299660     2022         1       골목상권       이북5도청사           0
# 299661     2022         1       골목상권       이북5도청사           0
# 299662     2022         1       골목상권       이북5도청사           1
# 299663     2022         1       골목상권       이북5도청사           0
# 299664     2022         1       골목상권       이북5도청사           1
#
# [299665 rows x 5 columns]

# %%
# 상권_구분_코드_명 > 골목상권만 추출
df3 = df3[df3['상권_구분_코드_명'] == "골목상권"]
df3
# Out:
#         기준_년_코드  기준_분기_코드 상권_구분_코드_명  상권_코드_명  프랜차이즈_점포_수
# 29166      2022         4       골목상권  강일동주민센터           0
# 29167      2022         4       골목상권  강일동주민센터           0
# 29168      2022         4       골목상권  강일동주민센터           0
# 29169      2022         4       골목상권  강일동주민센터           0
# 29170      2022         4       골목상권  강일동주민센터           0
# ...         ...       ...        ...      ...         ...
# 299660     2022         1       골목상권   이북5도청사           0
# 299661     2022         1       골목상권   이북5도청사           0
# 299662     2022         1       골목상권   이북5도청사           1
# 299663     2022         1       골목상권   이북5도청사           0
# 299664     2022         1       골목상권   이북5도청사           1
#
# [182928 rows x 5 columns]

# %%
# 기준_년_코드 열 삭제
df4 = df3.drop('기준_년_코드', axis=1)
df4
# Out:
#         기준_분기_코드 상권_구분_코드_명  상권_코드_명  프랜차이즈_점포_수
# 29166          4       골목상권  강일동주민센터           0
# 29167          4       골목상권  강일동주민센터           0
# 29168          4       골목상권  강일동주민센터           0
# 29169          4       골목상권  강일동주민센터           0
# 29170          4       골목상권  강일동주민센터           0
# ...          ...        ...      ...         ...
# 299660         1       골목상권   이북5도청사           0
# 299661         1       골목상권   이북5도청사           0
# 299662         1       골목상권   이북5도청사           1
# 299663         1       골목상권   이북5도청사           0
# 299664         1       골목상권   이북5도청사           1
#
# [182928 rows x 4 columns]

# %%
# 상권_코드_명 합치기
result = df4.groupby('상권_코드_명')['프랜차이즈_점포_수'].sum().reset_index()
result
# Out:
#            상권_코드_명  프랜차이즈_점포_수
# 0     4.19민주묘지역 2번          61
# 1        GS강동자이아파트          85
# 2              G타워         115
# 3     KB국민은행 망원동지점          69
# 4      KB국민은행 서강지점          18
# ...            ...         ...
# 1085     효창공원앞역 6번          62
# 1086       효창동주민센터          13
# 1087       후암동주민센터          86
# 1088          흑리단길          55
# 1089       흑석2치안센터           4
#
# [1090 rows x 2 columns]

# %%
# 분기 별 평균값 구하기
result['프랜차이즈_점포_수'] = result['프랜차이즈_점포_수'] / 4
result
# Out:
#            상권_코드_명  프랜차이즈_점포_수
# 0     4.19민주묘지역 2번       15.25
# 1        GS강동자이아파트       21.25
# 2              G타워       28.75
# 3     KB국민은행 망원동지점       17.25
# 4      KB국민은행 서강지점        4.50
# ...            ...         ...
# 1085     효창공원앞역 6번       15.50
# 1086       효창동주민센터        3.25
# 1087       후암동주민센터       21.50
# 1088          흑리단길       13.75
# 1089       흑석2치안센터        1.00
#
# [1090 rows x 2 columns]

# %%
# 소수점 버림
result['프랜차이즈_점포_수']=result['프랜차이즈_점포_수'].apply(lambda x: int(x))
result
# Out:
#            상권_코드_명  프랜차이즈_점포_수
# 0     4.19민주묘지역 2번          15
# 1        GS강동자이아파트          21
# 2              G타워          28
# 3     KB국민은행 망원동지점          17
# 4      KB국민은행 서강지점           4
# ...            ...         ...
# 1085     효창공원앞역 6번          15
# 1086       효창동주민센터           3
# 1087       후암동주민센터          21
# 1088          흑리단길          13
# 1089       흑석2치안센터           1
#
# [1090 rows x 2 columns]

# %%
# 새로운 csv 파일로 저장
result.to_csv("/Users/crlee/pandas/2022_프렌차이즈수_.csv",encoding = 'cp949', index=False)

# %%
df2= pd.read_csv("/Users/crlee/pandas/2022_프렌차이즈수_.csv",encoding = 'cp949')
df2
# Out:
#            상권_코드_명  프랜차이즈_점포_수
# 0     4.19민주묘지역 2번          15
# 1        GS강동자이아파트          21
# 2              G타워          28
# 3     KB국민은행 망원동지점          17
# 4      KB국민은행 서강지점           4
# ...            ...         ...
# 1085     효창공원앞역 6번          15
# 1086       효창동주민센터           3
# 1087       후암동주민센터          21
# 1088          흑리단길          13
# 1089       흑석2치안센터           1
#
# [1090 rows x 2 columns]
