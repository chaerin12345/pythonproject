# %%
# 필요 모듈 import
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt #그래프 패키지 모듈 등록
# %matplotlib inline 
# 트리맵 시각화
import squarify

# 한 셀에서 여러 변수 출력코드
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity="all"

# 한글 문제
# matplotlit의 기본 폰트에서 한글 지원되지 않기 때문에
# matplotlib의 폰트 변경 필요
import platform

from matplotlib import font_manager, rc
plt.rcParams['axes.unicode_minus'] = False

if platform.system() == 'Darwin':  # 맥OS 
    rc('font', family='AppleGothic')
elif platform.system() == 'Windows':  # 윈도우
    path = "c:/Windows/Fonts/malgun.ttf"
    font_name = font_manager.FontProperties(fname=path).get_name()
    rc('font', family=font_name)
else:
    print('Unknown system...  sorry~~~')

# %%
df = pd.read_csv("/Users/crlee/pandas/서울시_골목상권_재범주.csv",encoding='cp949',low_memory=False)
df
# Out:
#                  상권_코드_명    상권별_매출액_평균  프랜차이즈_점포_수   식료품_지출_총금액  의류_신발_지출_총금액  \
# 0           4.19민주묘지역 2번  1.787499e+08          15  153409088.0    66086125.0
# 1              KT&G 북부지사  1.489174e+08           4  103482570.0    33922469.0
# 2                가오리역 1번  1.736823e+08          13  134732302.0    61000987.0
# 3                가오리역 2번  1.330093e+08           6  345845765.0   154382931.0
# 4                   강북구청  1.955185e+08           9  236654594.0    90436416.0
# ...                  ...           ...         ...          ...           ...
# 1082              청계산원터골  7.587535e+08           2   24543421.0    10622543.0
# 1083  청계산입구역 2번(내곡동주민센터)  5.359684e+08           0   87820910.0    43203576.0
# 1084          한국상담대학원대학교  6.713270e+08           1   46411277.0    25402871.0
# 1085              한전아트센터  6.967944e+07           2   86420436.0    47052803.0
# 1086              헌인가구단지  2.221381e+08           0    9624270.0     4164242.0
#
# ...

# %% [markdown]
# ### 필요한 열만 추출

# %%
select_col = [ '프랜차이즈_점포_수','시군구_명','상권_코드_명','상권별_매출액_평균']
df2 = df[select_col]
df2
# Out:
#       프랜차이즈_점포_수 시군구_명             상권_코드_명    상권별_매출액_평균
# 0             15   강북구        4.19민주묘지역 2번  1.787499e+08
# 1              4   강북구           KT&G 북부지사  1.489174e+08
# 2             13   강북구             가오리역 1번  1.736823e+08
# 3              6   강북구             가오리역 2번  1.330093e+08
# 4              9   강북구                강북구청  1.955185e+08
# ...          ...   ...                 ...           ...
# 1082           2   서초구              청계산원터골  7.587535e+08
# 1083           0   서초구  청계산입구역 2번(내곡동주민센터)  5.359684e+08
# 1084           1   서초구          한국상담대학원대학교  6.713270e+08
# 1085           2   서초구              한전아트센터  6.967944e+07
# 1086           0   서초구              헌인가구단지  2.221381e+08
#
# [1087 rows x 4 columns]

# %% [markdown]
# ### 시군구명을 기준으로 합계

# %%
df2 = df2.groupby('시군구_명')['상권별_매출액_평균'].sum().reset_index()
df2
# Out:
#    시군구_명    상권별_매출액_평균
# 0    강남구  1.591431e+10
# 1    강동구  9.926953e+09
# 2    강북구  7.926159e+09
# 3    강서구  1.423294e+10
# 4    관악구  1.076437e+10
# 5    광진구  8.762014e+09
# 6    구로구  8.792385e+09
# 7    금천구  7.559216e+09
# 8    노원구  6.085392e+09
# 9    도봉구  8.426928e+09
# 10  동대문구  1.339057e+10
# 11   동작구  6.549929e+09
# 12   마포구  1.584007e+10
# 13  서대문구  9.222857e+09
# 14   서초구  1.108744e+10
# 15   성동구  1.168813e+10
# 16   성북구  1.185047e+10
# 17   송파구  1.351927e+10
# 18   양천구  7.278285e+09
# 19  영등포구  1.712880e+10
# 20   용산구  1.630914e+10
# 21   은평구  1.061351e+10
# 22   종로구  7.639490e+09
# 23    중구  5.355615e+09
# 24   중랑구  1.046282e+10

# %% [markdown]
# ### 상권별_매출액_평균으로 내림차순

# %%
df4 = df2.sort_values('상권별_매출액_평균', ascending=False)
df4
# Out:
#    시군구_명    상권별_매출액_평균
# 19  영등포구  1.712880e+10
# 20   용산구  1.630914e+10
# 0    강남구  1.591431e+10
# 12   마포구  1.584007e+10
# 3    강서구  1.423294e+10
# 17   송파구  1.351927e+10
# 10  동대문구  1.339057e+10
# 16   성북구  1.185047e+10
# 15   성동구  1.168813e+10
# 14   서초구  1.108744e+10
# 4    관악구  1.076437e+10
# 21   은평구  1.061351e+10
# 24   중랑구  1.046282e+10
# 1    강동구  9.926953e+09
# 13  서대문구  9.222857e+09
# 6    구로구  8.792385e+09
# 5    광진구  8.762014e+09
# 9    도봉구  8.426928e+09
# 2    강북구  7.926159e+09
# 22   종로구  7.639490e+09
# 7    금천구  7.559216e+09
# 18   양천구  7.278285e+09
# 11   동작구  6.549929e+09
# 8    노원구  6.085392e+09
# 23    중구  5.355615e+09

# %%
# 상위 5개 행 추출
top_5 = df4.head(5)

# 하위 5개 행 추출
bottom_5 = df4.tail(5)

# %% [markdown]
# ### 상위 5개 시각화

# %%
sizes = top_5['상권별_매출액_평균'].values
squarify.plot(sizes = sizes,label= top_5['시군구_명'],alpha=0.8)
plt.axis('off')
plt.title('총매출액 상위 5개 시군구')

plt.show()
# Out:
# <Axes: >
# (0.0, 100.0, 0.0, 100.0)
# Text(0.5, 1.0, '총매출액 상위 5개 시군구')

# %% [markdown]
# ### 하위 5개 시각화

# %%
sizes = bottom_5['상권별_매출액_평균'].values
squarify.plot(sizes = sizes,label= bottom_5['시군구_명'],alpha=0.8)
plt.axis('off')
plt.title('총매출액 하위 5개 시군구')

plt.show()
# Out:
# <Axes: >
# (0.0, 100.0, 0.0, 100.0)
# Text(0.5, 1.0, '총매출액 하위 5개 시군구')
